# %% [markdown]
# # 실습용 DB에서 "customerdata"테이블을 Python에서 불러오세요.

# %%
import pandas as pd
from sqlalchemy import create_engine

#DB커넥션 열기
engine = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl')

# DB 테이블을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_sql_query('SELECT * FROM customerdata', engine) 

# 컬럼해더 재정의
customerData.columns = ['CUSTID','AVGPRICE','EMI','DEVICECOUNT','PRODUCTAGE','CUSTTYPE']

# 데이터 VIEW
print(customerData.head())

customerData.head()
# Out:
#    CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  E11917  3516.500000    2          5.5    2.087540  Big-Screen-lover
# 1  E16075  3418.048887    2          4.2    2.771469      Sleeping-dog
# 2  E16221  3408.300000    2          5.0    1.988682  Big-Screen-lover
# 3  E18145  3408.300000    2          4.9    1.521029  Big-Screen-lover
# 4  E19404  3764.940414    2          6.5    0.900000        Early-bird
#      CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 8    F17131  3179.708359    3          6.5    1.100000        Early-bird
# 14   G16437  3787.328898    3          6.7    1.000000        Early-bird
# 17   G18402  3402.199381    3          6.5    1.000000        Early-bird
# 21   H16326  3988.935304    3          6.5    0.900000        Early-bird
# 26   I12899  3018.895637    3          6.4    0.900000        Early-bird
# 32   J10809  3676.135627    3          6.5    0.800000        Early-bird
# ...

# %% [markdown]
# # 1. 원하는 행(레코드) 조회하기

# %%
import pandas as pd
from sqlalchemy import create_engine

#DB커넥션 열기
engine = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl')

# DB 테이블을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_sql_query('SELECT * FROM customerdata', engine)

# 컬럼해더 재정의
customerData.columns = ['CUSTID','AVGPRICE','EMI','DEVICECOUNT','PRODUCTAGE','CUSTTYPE']

# 데이터 VIEW
print(customerData.head())

# 조건설정
answer2 = customerData.query("EMI==3 & DEVICECOUNT >5 ")
answer2
# Out:
#    CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  E11917  3516.500000    2          5.5    2.087540  Big-Screen-lover
# 1  E16075  3418.048887    2          4.2    2.771469      Sleeping-dog
# 2  E16221  3408.300000    2          5.0    1.988682  Big-Screen-lover
# 3  E18145  3408.300000    2          4.9    1.521029  Big-Screen-lover
# 4  E19404  3764.940414    2          6.5    0.900000        Early-bird
#      CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 8    F17131  3179.708359    3          6.5    1.100000        Early-bird
# 14   G16437  3787.328898    3          6.7    1.000000        Early-bird
# 17   G18402  3402.199381    3          6.5    1.000000        Early-bird
# 21   H16326  3988.935304    3          6.5    0.900000        Early-bird
# 26   I12899  3018.895637    3          6.4    0.900000        Early-bird
# 32   J10809  3676.135627    3          6.5    0.800000        Early-bird
# ...

# %% [markdown]
# # kopo_customerdata 테이블에서 gender==male이면서 email > 0 인 데이터를 추출하세요.

# %%
import pandas as pd
from sqlalchemy import create_engine

#DB커넥션 열기
engine = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl')

# DB 테이블을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_sql_query('SELECT * FROM kopo_customerdata', engine)

# 컬럼해더 재정의
#customerData.columns = ['CUSTID','AVGPRICE','EMI','DEVICECOUNT','PRODUCTAGE','CUSTTYPE']

# 데이터 VIEW
#print(customerData.head())

# 조건 설정
#answer = customerData[(customerData.gender=="Male")&(customerData.email>0)]
answer = customerData.query('gender=="Male" & email > 0')
print(answer)
# Out:
#        customercode statename  st gender  dob  gender1  email  fest_cnt  \
# 0           1503989    State2   2   Male    0        1      1         0
# 16          1154228    State2   2   Male    0        1      1         0
# 81           393246    State2   2   Male    0        1      1         1
# 206         2532568    State2   2   Male    1        1      1         0
# 216          487928    State2   2   Male    0        1      1         0
# 226         2452240    State2   2   Male    1        1      1         1
# 299         1295854    State2   2   Male    1        1      1         2
# 308          554757    State2   2   Male    0        1      1         0
# 330          761018    State2   2   Male    1        1      1         0
# 367         2191152    State2   2   Male    0        1      1         1
# 375          867914    State2   2   Male    0        1      1         0
# 415         1804886    State2   2   Male    0        1      1         1
# ...

# %% [markdown]
# ## 다른풀이

# %%
import pandas as pd
from sqlalchemy import create_engine

#DB커넥션 열기
engine = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl')

# DB 테이블을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_sql_query('SELECT * FROM kopo_customerdata where 1=1 and gender ='"'Male'"' and email >0', engine)

# 데이터 VIEW
customerData
# Out:
#      customercode statename  st gender  dob  gender1  email  fest_cnt  \
# 0         1503989    State2   2   Male    0        1      1         0
# 1         1154228    State2   2   Male    0        1      1         0
# 2          393246    State2   2   Male    0        1      1         1
# 3         2532568    State2   2   Male    1        1      1         0
# 4          487928    State2   2   Male    0        1      1         0
# 5         2452240    State2   2   Male    1        1      1         1
# 6         1295854    State2   2   Male    1        1      1         2
# 7          554757    State2   2   Male    0        1      1         0
# 8          761018    State2   2   Male    1        1      1         0
# 9         2191152    State2   2   Male    0        1      1         1
# 10         867914    State2   2   Male    0        1      1         0
# 11        1804886    State2   2   Male    0        1      1         1
# ...

# %%
#라이브러리 메소드 목록 조회

# %%
import itertools as it
dir(it)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_grouper',
#  '_tee',
#  '_tee_dataobject',
#  'accumulate',
#  'chain',
#  'combinations',
#  'combinations_with_replacement',
#  'compress',
#  'count',
#  'cycle',
#  'dropwhile',
#  'filterfalse',
#  'groupby',
#  'islice',
#  'permutations',
#  'product',
#  'repeat',
#  'starmap',
#  'takewhile',
#  'tee',
#  'zip_longest']

# %%
#repeat만 필요한경우
from itertools import repeat as rpt
rpt(10,5)
# Out:
# repeat(10, 5)

# %% [markdown]
# # kopo_customerdata 테이블에서customercode, statename, gender, total_amount 컬럼만 추출하세요

# %%
import pandas as pd
from sqlalchemy import create_engine

#DB커넥션 열기
engine = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl')

# DB 테이블을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_sql_query('SELECT * FROM kopo_customerdata', engine)

customerDataC = customerData[['customercode','statename','gender','total_amount']]

customerDataC
# Out:
#        customercode statename  gender  total_amount
# 0           1503989    State2    Male         30300
# 1           1190338    State2    Male         46500
# 2           1424715    State2  Female         22700
# 3           2483305    State2    Male         31400
# 4           1178802    State2    Male         44900
# 5            859044    State2    Male         38300
# 6            734198    State2  Female         19900
# 7           1443485    State2  Female         14800
# 8           2340520    State2    Male         24400
# 9            697949    State2    Male         30400
# 10           385031    State2    Male         30300
# 11          1944258    State2  Female         34300
# 12          2029521    State2  Female         14900
# 13          1429192    State2    Male         16300
# 14           892851    State2    Male         25000
# 15          1554976    State2    Male         27500
# 16          1154228    State2    Male         18200
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

#DB커넥션 열기
engine = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl')

# DB 테이블을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_sql_query('SELECT * FROM kopo_customerdata', engine)


dfc1 = customerData.iloc[0:1,:]
dfc1
# Out:
#   customercode statename  st gender  dob  gender1  email  fest_cnt  \
# 0      1503989    State2   2   Male    0        1      1         0
#
#    total_amount  ac_amount  av_amount  ha_amount  emi_ce_amount  is_highend  \
# 0         30300          0      30300          0              0           0
#
#    cnt_vist  gap_visit
# 0         1          0

# %% [markdown]
# # kopo_customerdata 테이블에서 0~5번째 행의 statename, gender를 선택하세요(인덱스 활용)

# %%
import pandas as pd
from sqlalchemy import create_engine

#DB커넥션 열기
engine = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl')

# DB 테이블을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_sql_query('SELECT * FROM kopo_customerdata', engine)


# 인덱스 활용
dfc = customerData.iloc[0:5,[1,3]]
dfc
# Out:
#   customercode statename  st  gender  dob  gender1  email  fest_cnt  \
# 0      1503989    State2   2    Male    0        1      1         0
# 1      1190338    State2   2    Male    0        1      0         1
# 2      1424715    State2   2  Female    0        2      0         0
# 3      2483305    State2   2    Male    0        1      0         1
# 4      1178802    State2   2    Male    0        1      0         1
#
#    total_amount  ac_amount  av_amount  ha_amount  emi_ce_amount  is_highend  \
# 0         30300          0      30300          0              0           0
# 1         46500          0      46500          0              0           0
# 2         22700          0          0      22700              0           0
# 3         31400          0      31400          0              0           0
# 4         44900          0          0      44900              0           0
#
#    cnt_vist  gap_visit
# 0         1          0
# 1         1          0
# 2         1          0
# ...

# %%
customerData
# Out:
#        customercode statename  st  gender  dob  gender1  email  fest_cnt  \
# 0           1503989    State2   2    Male    0        1      1         0
# 1           1190338    State2   2    Male    0        1      0         1
# 2           1424715    State2   2  Female    0        2      0         0
# 3           2483305    State2   2    Male    0        1      0         1
# 4           1178802    State2   2    Male    0        1      0         1
# 5            859044    State2   2    Male    0        1      0         0
# 6            734198    State2   2  Female    0        2      0         0
# 7           1443485    State2   2  Female    0        2      0         0
# 8           2340520    State2   2    Male    0        1      0         1
# 9            697949    State2   2    Male    0        1      0         1
# 10           385031    State2   2    Male    0        1      0         1
# 11          1944258    State2   2  Female    0        2      0         0
# ...
