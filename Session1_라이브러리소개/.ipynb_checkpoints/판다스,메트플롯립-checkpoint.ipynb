# %%
import pandas_datareader.data as web
import fix_yahoo_finance as yf
yf.pdr_override()
from datetime import date, timedelta
import matplotlib.pyplot as plt
import datetime

start = datetime.datetime(2017,4,1)
end = date.today()

# %%
SEC = web.get_data_yahoo("005930.KS",start,end)
SEC['Close'].plot(style='--')
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 downloaded

# %%
import numpy as np
# 0,5사이에 11개의 점을 생성한다
x = np.linspace(0,5,11)
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
import numpy as np
# 0,5 사이에 11개의 점을 생성한다.
x= np.linspace(0,5,11)
# y = x의 제곱
y= x**2
#시각화
plt.plot(x,y)

# %%
import numpy as np
data = np.loadtxt('C:/Users/SMART-17/PythonSession/dataset/test.txt'
                 ,delimiter=',' )
print(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-06965856e3bd> in <module>()
#       1 import numpy as np
#       2 data = np.loadtxt('C:/Users/SMART-17/PythonSession/dataset/test.txt'
# ----> 3                  ,delimeter=',' )
#       4 print(data)
#
# TypeError: loadtxt() got an unexpected keyword argument 'delimeter'
