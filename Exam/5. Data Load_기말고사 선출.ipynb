# %% [markdown]
# ### CSV Connection

# %%
pwd
# Out:
# 'C:\\Users\\SMART-00\\Python Session\\Session3 - Learning basic grammar and data import'

# %%
# PANDAS 패키지 불러오기
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine 
# CSV 파일을 읽어 Data Frame 변수에 저장하기
elecData = pd.read_excel("d:/elec_data.xlsx")

# NAME컬럼만 선택
names = elecData.iloc[:,0:]
names
# Out:
#                     name
# 0                김의진,박승진
# 1                김의진,정경화
# 2               김의진, 박승진
# 3                김의진,박승진
# 4   \r\n\r\n\r\n김의진, 오미진
# 5               김의진, 오미진
# 6               박승진, 김의진
# 7                정경화,김의진
# 8                   김의진,
# 9                황원용,김효관
# 10              김의진, 신성우
# 11               김의진,김도운
# 12              김의진, 조정연
# 13              오미진, 조정연
# 14              김의진, 신성우
# 15              신성우, 김의진
# 16             김의진 , 신성우
# 17          정효재 님, 하태양 님
# 18              채성은, 정경화
# 19              조정연, 박승진
# 20              김의진, 김지성
# 21              이한민, 오미진
# 22             박승진 , 김의진
# 23               김의진,정유석

# %%
names
# Out:
#                     name
# 0                김의진,박승진
# 1                김의진,정경화
# 2               김의진, 박승진
# 3                김의진,박승진
# 4   \r\n\r\n\r\n김의진, 오미진
# 5               김의진, 오미진
# 6               박승진, 김의진
# 7                정경화,김의진
# 8                   김의진,
# 9                황원용,김효관
# 10              김의진, 신성우
# 11               김의진,김도운
# 12              김의진, 조정연
# 13              오미진, 조정연
# 14              김의진, 신성우
# 15              신성우, 김의진
# 16             김의진 , 신성우
# 17          정효재 님, 하태양 님
# 18              채성은, 정경화
# 19              조정연, 박승진
# 20              김의진, 김지성
# 21              이한민, 오미진
# 22             박승진 , 김의진
# 23               김의진,정유석

# %%
# PANDAS 패키지 불러오기
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine 
# CSV 파일을 읽어 Data Frame 변수에 저장하기
elecData = pd.read_excel("d:/elec_data.xlsx")

# NAME컬럼만 선택
names = elecData['name']

# 이름값만 추출하여 리스트에 저장
emptyList = []
names.head()

name = names[0].split(",")
len(name)
    for row in name:
        emptyList.append(row)


#for name in names:
# Out:
# 2

# %%
# PANDAS 패키지 불러오기
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine 
# CSV 파일을 읽어 Data Frame 변수에 저장하기
elecData = pd.read_excel("d:/elec_data.xlsx")

# NAME컬럼만 선택
names = elecData['name']

# 이름값만 추출하여 리스트에 저장
emptyList = []
for name in names:
    rows = name.strip().replace("'","").replace("님","").split(",")
    #emptyList.append()
    for row in rows:
        # 만약 NULL 이면 APPEND 하지 않는다면 NULL 값 자동 제거됨
        emptyList.append(row.strip())

## 리스트 -> 데이터프레임 변환
refinedData = pd.DataFrame(emptyList, columns=["NAME"])

## null 처리
finalResult = refinedData[refinedData['NAME'] != ""]

finalResult.head()
# Out:
#   NAME
# 0  김의진
# 1  박승진
# 2  김의진
# 3  정경화
# 4  김의진

# %%
# PANDAS 패키지 불러오기
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine 
# CSV 파일을 읽어 Data Frame 변수에 저장하기
elecData = pd.read_excel("d:/elec_data.xlsx")

# 컬럼해더 재정의
#elecData.columns = ['EMAIL','NAME']
# NAME컬럼만 선택
names = elecData.iloc[1]

# 이름값만 추출하여 리스트에 저장
emptyList = []
for name in names:
    rows = name.strip().replace("'","").replace("님","").split(",")
    #emptyList.append()
    for row in rows:
        # 만약 NULL 이면 APPEND 하지 않는다면 NULL 값 자동 제거됨
        emptyList.append(row.strip())
        
emptyList

## NULL 값 정제
refinedData = pd.DataFrame(emptyList, columns=["NAME"])
refinedData
finalResult = refinedData[refinedData['NAME'] != ""]

# DB 커넥션 열기
engine = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl') 
print(finalResult.dtypes)
# 데이터 저장
resultname='ELECRESULT2'
finalResult.to_sql(resultname, engine, if_exists='replace', index=False,  dtype={'NAME': sqlalchemy.types.VARCHAR(length=20) })
# Out:
# NAME    object
# dtype: object
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-116-242096a1df3d> in <module>()
#      32 # 데이터 저장
#      33 resultname='ELECRESULT2'
# ---> 34 finalResult.to_sql(resultname, engine, if_exists='replace', index=False,  dtype={'NAME': sqlalchemy.types.VARCHAR(length=20) })
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, flavor, schema, if_exists, index, index_label, chunksize, dtype)
#    1532         sql.to_sql(self, name, con, flavor=flavor, schema=schema,
#    1533                    if_exists=if_exists, index=index, index_label=index_label,
# -> 1534                    chunksize=chunksize, dtype=dtype)
#    1535
#    1536     def to_pickle(self, path, compression='infer',
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, flavor, schema, if_exists, index, index_label, chunksize, dtype)
#     471     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     472                       index_label=index_label, schema=schema,
# --> 473                       chunksize=chunksize, dtype=dtype)
#     474
#     475
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1153                          if_exists=if_exists, index_label=index_label,
#    1154                          schema=schema, dtype=dtype)
# -> 1155         table.create()
#    1156         table.insert(chunksize)
#    1157         if (not name.isdigit() and not name.islower()):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in create(self)
#     592                 raise ValueError("Table '%s' already exists." % self.name)
#     593             elif self.if_exists == 'replace':
# --> 594                 self.pd_sql.drop_table(self.name, self.schema)
#     595                 self._execute_create()
#     596             elif self.if_exists == 'append':
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in drop_table(self, table_name, schema)
#    1202         schema = schema or self.meta.schema
#    1203         if self.has_table(table_name, schema):
# -> 1204             self.meta.reflect(only=[table_name], schema=schema)
#    1205             self.get_table(table_name, schema).drop()
#    1206             self.meta.clear()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\sql\schema.py in reflect(self, bind, schema, views, only, extend_existing, autoload_replace, **dialect_kwargs)
#    3954                         'Could not reflect: requested table(s) not available '
#    3955                         'in %r%s: (%s)' %
# -> 3956                         (bind.engine, s, ', '.join(missing)))
#    3957                 load = [name for name in only if extend_existing or
#    3958                         name not in current]
#
# InvalidRequestError: Could not reflect: requested table(s) not available in Engine(oracle+cx_oracle://kopo:***@192.168.110.112:1521/orcl): (ELECRESULT2)

# %%
pwd
# Out:
# 'C:\\Users\\SMART-00\\Python Session\\Session3 - Learning basic grammar and data import'

# %%
refinedData.query()

# %%
a  ='김의진,박승진'
test = a.strip().replace("'","").split(",")
type(test[0])
# Out:
# str

# %%
# PANDAS 패키지 불러오기
import pandas as pd
 
# CSV 파일을 읽어 Data Frame 변수에 저장하기
elecData = pd.read_excel("d:/elec_data.xlsx")
elecData
# 컬럼해더 재정의
elecData.columns = ['EMAIL','NAME']
names = elecData['NAME']
refinedNames = []


for in names:
    refinedNames[].ap
# Out:
# '김의진,박승진'

# %%
# PANDAS 패키지 불러오기
import pandas as pd
 
# CSV 파일을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_csv("../dataset/customerdata.csv")

# 컬럼해더 재정의
customerData.columns = ['CUSTID','AVGPRICE','EMI','DEVICECOUNT','PRODUCTAGE','CUSTTYPE']

# 데이터 VIEW
    
# CSV 파일로 저장
customerData.to_csv("../dataset/customerdata_out.csv", encoding='utf-8-sig', index=False)
customerData.head()
# Out:
#    CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219  3642.441950    2          4.0    2.682023      Sleeping-dog
# 2  A15312  3653.884565    2          5.0    3.208202      Sleeping-dog
# 3  A16605  3713.211107    2          6.6    0.900000        Early-bird
# 4  B10634  3391.074215    2          4.2    2.453656      Sleeping-dog

# %% [markdown]
# ### Oracle connection

# %%
import pandas as pd
from sqlalchemy import create_engine 
 
# DB 커넥션 열기
engine = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl') 

# DB 테이블을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_sql_query('SELECT * FROM customerdata', engine) 

# 컬럼해더 재정의
customerData.columns = ['CUSTID','AVGPRICE','EMI','DEVICECOUNT','PRODUCTAGE','CUSTTYPE']

# 데이터 VIEW
print(customerData.head())

# 데이터 저장
resultname='oracleresult'
customerData.to_sql(resultname, engine, if_exists='replace', index=False)
# Out:
#    CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219  3642.441950    2          4.0    2.682023      Sleeping-dog
# 2  A15312  3653.884565    2          5.0    3.208202      Sleeping-dog
# 3  A16605  3713.211107    2          6.6    0.900000        Early-bird
# 4  B10634  3391.074215    2          4.2    2.453656      Sleeping-dog

# %%
import pandas as pd
from sqlalchemy import create_engine 
 
# DB 커넥션 열기
engine = create_engine('oracle+cx_oracle://kopo:kopo@127.0.0.1:1521/xe') 

# DB 테이블을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_sql_query('SELECT * FROM kopo_product_volume', engine) 

# 컬럼해더 재정의
customerData.columns = ['REGIONID','PRODUCTGROUP','YEARWEEK','VOLUME']

# 데이터 VIEW
print(customerData.head())

# 데이터 저장
engine2 = create_engine('mysql+pymysql://kopo:kopo1234@kopo2.cf0xvfbyuytw.us-east-1.rds.amazonaws.com:3306/kopo') 
resultname='kopo_product_volume'
customerData.to_sql(resultname, engine2, if_exists='replace', index=False)
# Out:
#   REGIONID PRODUCTGROUP YEARWEEK  VOLUME
# 0      A01       ST0002   201512  151750
# 1      A01       ST0001   201520  645626
# 2      A01       ST0002   201520  125863
# 3      A01       ST0001   201515  810144
# 4      A01       ST0002   201515  128999

# %% [markdown]
# ### Mysql connection

# %%
# PANDAS 패키지 불러오기
import pandas as pd 
import pymysql 
from sqlalchemy import create_engine 
 
# DB 커넥션 열기
engine = create_engine('mysql+pymysql://kopo:kopo1234@kopo2.cf0xvfbyuytw.us-east-1.rds.amazonaws.com:3306/kopo') 

# DB 테이블을 읽어 Data Frame 변수에 저장하기
storeData = pd.read_sql_query('SELECT * FROM store_location', engine) 
storeData.head()
# Out:
#                   cs_name         lng        lat
# 0  coffeekorea_seulleng93  127.047883  37.505675
# 1                 propose  126.899220  37.471711
# 2    singsingcoffee_toast  128.980455  35.159774
# 3            warawara_hof  127.061026  37.493922
# 4                    test  126.715710  37.460813

# %%
# 컬럼해더 재정의
storeData.columns = ['CS_NAME','LNG','LAT']

# 데이터 VIEW
print(storeData)

# 데이터 저장
resultname='mysqlresult'
storeData.to_sql(resultname, engine, if_exists='replace', index=False)
# Out:
#                   CS_NAME         LNG         LAT
# 0  coffeekorea_seulleng93  127.047883   37.505675
# 1                 propose  126.899220   37.471711
# 2    singsingcoffee_toast  128.980455   35.159774
# 3            warawara_hof  127.061026   37.493922
# 4                    test  126.715710   37.460813
# 5        polytech_kangseo   37.549506  126.840918
# 6       polytech_kangseo2  126.840918   37.549506

# %% [markdown]
# ### Sql Server

# %%
import pandas as pd
from sqlalchemy import create_engine 
 
# DB 커넥션 열기
engine_oracle = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl') 
engine_mssql = create_engine('mssql+pymssql://haiteam:kopo1234!@192.168.0.6:1433/kopo') 

# DB 테이블을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_sql_query('SELECT * FROM kopo_product_volume', engine_oracle) 

# 컬럼해더 재정의
customerData.columns = ['REGIONID','PRODUCTGROUP','YEARWEEK','VOLUME']

# 데이터 VIEW
print(customerData.head())

# 데이터 저장
resultname='KOPO_PRODUCT_VOLUME'
customerData.to_sql(resultname, engine_mssql, if_exists='replace', index=False)
# Out:
#   REGIONID PRODUCTGROUP YEARWEEK  VOLUME
# 0      A01       ST0001   201501  513598
# 1      A01       ST0001   201502  438251
# 2      A01       ST0001   201503  420290
# 3      A01       ST0001   201504  458431
# 4      A01       ST0001   201505  482381
# ---------------------------------------------------------------------------
# MSSQLDatabaseException                    Traceback (most recent call last)
# pymssql.pyx in pymssql.connect (pymssql.c:10734)()
#
# _mssql.pyx in _mssql.connect (_mssql.c:21821)()
#
# _mssql.pyx in _mssql.MSSQLConnection.__init__ (_mssql.c:6581)()
#
# _mssql.pyx in _mssql.maybe_raise_MSSQLDatabaseException (_mssql.c:17524)()
#
# MSSQLDatabaseException: (20009, b'DB-Lib error message 20009, severity 9:\nUnable to connect: Adaptive Server is unavailable or does not exist (192.168.0.6:1433)\nNet-Lib error during Unknown error (10060)\n')
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     402         if not self._use_threadlocal:
# --> 403             return _ConnectionFairy._checkout(self)
#     404
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     781         if not fairy:
# --> 782             fairy = _ConnectionRecord.checkout(pool)
#     783
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1185                 with util.safe_reraise():
# -> 1186                     self._dec_overflow()
#    1187         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1182             try:
# -> 1183                 return self._create_connection()
#    1184             except:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _create_connection(self)
#     349
# --> 350         return _ConnectionRecord(self)
#     351
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in __init__(self, pool, connect)
#     476         if connect:
# --> 477             self.__connect(first_connect_check=True)
#     478         self.finalize_callback = deque()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in __connect(self, first_connect_check)
#     666             self.starttime = time.time()
# --> 667             connection = pool._invoke_creator(self)
#     668             pool.logger.debug("Created new connection %r", connection)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     104                             return connection
# --> 105                 return dialect.connect(*cargs, **cparams)
#     106
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     409     def connect(self, *cargs, **cparams):
# --> 410         return self.dbapi.connect(*cargs, **cparams)
#     411
#
# pymssql.pyx in pymssql.connect (pymssql.c:10824)()
#
# OperationalError: (20009, b'DB-Lib error message 20009, severity 9:\nUnable to connect: Adaptive Server is unavailable or does not exist (192.168.0.6:1433)\nNet-Lib error during Unknown error (10060)\n')
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-1-bc4a6f5f09a9> in <module>()
#      17 # 데이터 저장
#      18 resultname='KOPO_PRODUCT_VOLUME'
# ---> 19 customerData.to_sql(resultname, engine_mssql, if_exists='replace', index=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, flavor, schema, if_exists, index, index_label, chunksize, dtype)
#    1532         sql.to_sql(self, name, con, flavor=flavor, schema=schema,
#    1533                    if_exists=if_exists, index=index, index_label=index_label,
# -> 1534                    chunksize=chunksize, dtype=dtype)
#    1535
#    1536     def to_pickle(self, path, compression='infer',
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, flavor, schema, if_exists, index, index_label, chunksize, dtype)
#     471     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     472                       index_label=index_label, schema=schema,
# --> 473                       chunksize=chunksize, dtype=dtype)
#     474
#     475
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1153                          if_exists=if_exists, index_label=index_label,
#    1154                          schema=schema, dtype=dtype)
# -> 1155         table.create()
#    1156         table.insert(chunksize)
#    1157         if (not name.isdigit() and not name.islower()):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in create(self)
#     588
#     589     def create(self):
# --> 590         if self.exists():
#     591             if self.if_exists == 'fail':
#     592                 raise ValueError("Table '%s' already exists." % self.name)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in exists(self)
#     576
#     577     def exists(self):
# --> 578         return self.pd_sql.has_table(self.name, self.schema)
#     579
#     580     def sql_schema(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1181             self.connectable.dialect.has_table,
#    1182             name,
# -> 1183             schema or self.meta.schema,
#    1184         )
#    1185
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in run_callable(self, callable_, *args, **kwargs)
#    2053
#    2054         """
# -> 2055         with self.contextual_connect() as conn:
#    2056             return conn.run_callable(callable_, *args, **kwargs)
#    2057
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in contextual_connect(self, close_with_result, **kwargs)
#    2121         return self._connection_cls(
#    2122             self,
# -> 2123             self._wrap_pool_connect(self.pool.connect, None),
#    2124             close_with_result=close_with_result,
#    2125             **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2160             if connection is None:
#    2161                 Connection._handle_dbapi_exception_noconnection(
# -> 2162                     e, dialect, self)
#    2163             else:
#    2164                 util.reraise(*sys.exc_info())
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1474             util.raise_from_cause(
#    1475                 sqlalchemy_exception,
# -> 1476                 exc_info
#    1477             )
#    1478         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2156         dialect = self.dialect
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#    2160             if connection is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     401         """
#     402         if not self._use_threadlocal:
# --> 403             return _ConnectionFairy._checkout(self)
#     404
#     405         try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     780     def _checkout(cls, pool, threadconns=None, fairy=None):
#     781         if not fairy:
# --> 782             fairy = _ConnectionRecord.checkout(pool)
#     783
#     784             fairy._pool = pool
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     530     @classmethod
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#     534             dbapi_connection = rec.get_connection()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1184             except:
#    1185                 with util.safe_reraise():
# -> 1186                     self._dec_overflow()
#    1187         else:
#    1188             return self._do_get()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      64             self._exc_info = None   # remove potential circular references
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#      68             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     185         if value.__traceback__ is not tb:
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#     189 else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1181         if self._inc_overflow():
#    1182             try:
# -> 1183                 return self._create_connection()
#    1184             except:
#    1185                 with util.safe_reraise():
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _create_connection(self)
#     348         """Called by subclasses to create a new ConnectionRecord."""
#     349
# --> 350         return _ConnectionRecord(self)
#     351
#     352     def _invalidate(self, connection, exception=None, _checkin=True):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in __init__(self, pool, connect)
#     475         self.__pool = pool
#     476         if connect:
# --> 477             self.__connect(first_connect_check=True)
#     478         self.finalize_callback = deque()
#     479
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in __connect(self, first_connect_check)
#     665         try:
#     666             self.starttime = time.time()
# --> 667             connection = pool._invoke_creator(self)
#     668             pool.logger.debug("Created new connection %r", connection)
#     669             self.connection = connection
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     103                         if connection is not None:
#     104                             return connection
# --> 105                 return dialect.connect(*cargs, **cparams)
#     106
#     107             creator = pop_kwarg('creator', connect)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     408
#     409     def connect(self, *cargs, **cparams):
# --> 410         return self.dbapi.connect(*cargs, **cparams)
#     411
#     412     def create_connect_args(self, url):
#
# pymssql.pyx in pymssql.connect (pymssql.c:10824)()
#
# OperationalError: (pymssql.OperationalError) (20009, b'DB-Lib error message 20009, severity 9:\nUnable to connect: Adaptive Server is unavailable or does not exist (192.168.0.6:1433)\nNet-Lib error during Unknown error (10060)\n') (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
a=3
b=5
print(a+b)
# Out:
# 8

# %%
# PANDAS 패키지 불러오기
import pandas as pd 
import pymssql 
from sqlalchemy import create_engine 
 
def executeQuery(sql_query):
    connection_string = 'mssql+pymssql://haiteam:kopo1234!@192.168.110.107:1433/kopo'
    engine = create_engine(connection_string)

    df = pd.read_sql(sql_query, engine)

    return df

# DB 테이블을 읽어 Data Frame 변수에 저장하기
storeData =executeQuery("select * from kopo_product_volume")
storeData.head()
# Out:
# ---------------------------------------------------------------------------
# MSSQLDatabaseException                    Traceback (most recent call last)
# pymssql.pyx in pymssql.connect (pymssql.c:10734)()
#
# _mssql.pyx in _mssql.connect (_mssql.c:21821)()
#
# _mssql.pyx in _mssql.MSSQLConnection.__init__ (_mssql.c:6581)()
#
# _mssql.pyx in _mssql.maybe_raise_MSSQLDatabaseException (_mssql.c:17524)()
#
# MSSQLDatabaseException: (20009, b'DB-Lib error message 20009, severity 9:\nUnable to connect: Adaptive Server is unavailable or does not exist (192.168.110.107:1433)\nNet-Lib error during Unknown error (10060)\n')
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     402         if not self._use_threadlocal:
# --> 403             return _ConnectionFairy._checkout(self)
#     404
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     781         if not fairy:
# --> 782             fairy = _ConnectionRecord.checkout(pool)
#     783
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1185                 with util.safe_reraise():
# -> 1186                     self._dec_overflow()
#    1187         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1182             try:
# -> 1183                 return self._create_connection()
#    1184             except:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _create_connection(self)
#     349
# --> 350         return _ConnectionRecord(self)
#     351
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in __init__(self, pool, connect)
#     476         if connect:
# --> 477             self.__connect(first_connect_check=True)
#     478         self.finalize_callback = deque()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in __connect(self, first_connect_check)
#     666             self.starttime = time.time()
# --> 667             connection = pool._invoke_creator(self)
#     668             pool.logger.debug("Created new connection %r", connection)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     104                             return connection
# --> 105                 return dialect.connect(*cargs, **cparams)
#     106
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     409     def connect(self, *cargs, **cparams):
# --> 410         return self.dbapi.connect(*cargs, **cparams)
#     411
#
# pymssql.pyx in pymssql.connect (pymssql.c:10824)()
#
# OperationalError: (20009, b'DB-Lib error message 20009, severity 9:\nUnable to connect: Adaptive Server is unavailable or does not exist (192.168.110.107:1433)\nNet-Lib error during Unknown error (10060)\n')
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-52-2b87a4629bdd> in <module>()
#      13
#      14 # DB 테이블을 읽어 Data Frame 변수에 저장하기
# ---> 15 storeData =executeQuery("select * from kopo_product_volume")
#      16 storeData.head()
#
# <ipython-input-52-2b87a4629bdd> in executeQuery(sql_query)
#       8     engine = create_engine(connection_string)
#       9
# ---> 10     df = pd.read_sql(sql_query, engine)
#      11
#      12     return df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     414             sql, index_col=index_col, params=params,
#     415             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 416             chunksize=chunksize)
#     417
#     418
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1090         args = _convert_params(sql, params)
#    1091
# -> 1092         result = self.execute(*args)
#    1093         columns = result.keys()
#    1094
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#     981     def execute(self, *args, **kwargs):
#     982         """Simple passthrough to SQLAlchemy connectable"""
# --> 983         return self.connectable.execute(*args, **kwargs)
#     984
#     985     def read_table(self, table_name, index_col=None, coerce_float=True,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    2072         """
#    2073
# -> 2074         connection = self.contextual_connect(close_with_result=True)
#    2075         return connection.execute(statement, *multiparams, **params)
#    2076
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in contextual_connect(self, close_with_result, **kwargs)
#    2121         return self._connection_cls(
#    2122             self,
# -> 2123             self._wrap_pool_connect(self.pool.connect, None),
#    2124             close_with_result=close_with_result,
#    2125             **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2160             if connection is None:
#    2161                 Connection._handle_dbapi_exception_noconnection(
# -> 2162                     e, dialect, self)
#    2163             else:
#    2164                 util.reraise(*sys.exc_info())
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1474             util.raise_from_cause(
#    1475                 sqlalchemy_exception,
# -> 1476                 exc_info
#    1477             )
#    1478         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2156         dialect = self.dialect
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#    2160             if connection is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     401         """
#     402         if not self._use_threadlocal:
# --> 403             return _ConnectionFairy._checkout(self)
#     404
#     405         try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     780     def _checkout(cls, pool, threadconns=None, fairy=None):
#     781         if not fairy:
# --> 782             fairy = _ConnectionRecord.checkout(pool)
#     783
#     784             fairy._pool = pool
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     530     @classmethod
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#     534             dbapi_connection = rec.get_connection()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1184             except:
#    1185                 with util.safe_reraise():
# -> 1186                     self._dec_overflow()
#    1187         else:
#    1188             return self._do_get()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      64             self._exc_info = None   # remove potential circular references
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#      68             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     185         if value.__traceback__ is not tb:
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#     189 else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1181         if self._inc_overflow():
#    1182             try:
# -> 1183                 return self._create_connection()
#    1184             except:
#    1185                 with util.safe_reraise():
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _create_connection(self)
#     348         """Called by subclasses to create a new ConnectionRecord."""
#     349
# --> 350         return _ConnectionRecord(self)
#     351
#     352     def _invalidate(self, connection, exception=None, _checkin=True):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in __init__(self, pool, connect)
#     475         self.__pool = pool
#     476         if connect:
# --> 477             self.__connect(first_connect_check=True)
#     478         self.finalize_callback = deque()
#     479
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in __connect(self, first_connect_check)
#     665         try:
#     666             self.starttime = time.time()
# --> 667             connection = pool._invoke_creator(self)
#     668             pool.logger.debug("Created new connection %r", connection)
#     669             self.connection = connection
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     103                         if connection is not None:
#     104                             return connection
# --> 105                 return dialect.connect(*cargs, **cparams)
#     106
#     107             creator = pop_kwarg('creator', connect)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     408
#     409     def connect(self, *cargs, **cparams):
# --> 410         return self.dbapi.connect(*cargs, **cparams)
#     411
#     412     def create_connect_args(self, url):
#
# pymssql.pyx in pymssql.connect (pymssql.c:10824)()
#
# OperationalError: (pymssql.OperationalError) (20009, b'DB-Lib error message 20009, severity 9:\nUnable to connect: Adaptive Server is unavailable or does not exist (192.168.110.107:1433)\nNet-Lib error during Unknown error (10060)\n') (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
import requests, bs4, pandas as pd
#웹페이지 html 소스 가져오기
resp = requests.get('http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp')
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')

for i in  bs
# Out:
# bs4.element.Tag

# %% [markdown]
# ### Data load from web

# %%
import requests, bs4, pandas as pd
#웹페이지 html 소스 가져오기
resp = requests.get('http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp')
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')

# html 구조 태그로 가져오기
title = bs.find("title").text
wf = bs.find("wf").text
print(title)
print(wf)
# Out:
# 기상청 육상 중기예보
# 이번 예보기간에는 고기압의 영향으로 대체로 맑은 날이 많겠습니다.  <br />기온은 평년(최저기온: 15~20도, 최고기온: 22~29도)과 전반에는 비슷하겠고, 후반에는 조금 높겠습니다.<br />강수량은 평년(3~19mm)보다 적겠습니다.

# %% [markdown]
# ### 1. 태그 찾기 - find

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://13.209.33.89:3333/quiz')
resp.encoding='utf-8'

# %%
resp.text
bs = bs4.BeautifulSoup(html, "html.parser")
bs
# Out:
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link/>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubdate>2018년 06월 14일 (목)요일 06:00</pubdate>
# <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>전국 육상 중기예보 - 2018년 06월 14일 (목)요일 06:00 발표</title>
# <link/>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</guid>
# <description>
# <header>
# <title>전국 육상중기예보</title>
# <tm>201806140600</tm>
# <wf><![CDATA[이번 예보기간에는 고기압의 영향으로 대체로 맑은 날이 많겠습니다.  <br />기온은 평년(최저기온: 15~20도, 최고기온: 22~29도)과 전반에는 비슷하겠고, 후반에는 조금 높겠습니다.<br />강수량은 평년(3~19mm)보다 적겠습니다.]]></wf>
# </header>
# <body>
# <location wl_ver="3">
# <province>서울ㆍ인천ㆍ경기도</province>
# <city>서울</city>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>18</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-22 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-23 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-24 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# </location>
# <location wl_ver="3">
# <province>서울ㆍ인천ㆍ경기도</province>
# <city>인천</city>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>25</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>18</tmn>
# <tmx>25</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>25</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>25</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-22 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>19</tmn>
# <tmx>25</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-23 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>19</tmn>
# <tmx>25</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-24 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>19</tmn>
# <tmx>25</tmx>
# <reliability>보통</reliability>
# </data>
# </location>
# <location wl_ver="3">
# <province>서울ㆍ인천ㆍ경기도</province>
# <city>수원</city>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>18</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-22 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-23 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-24 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# </location>
# <location wl_ver="3">
# <province>서울ㆍ인천ㆍ경기도</province>
# <city>파주</city>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>16</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>16</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>17</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>17</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>17</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>17</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-22 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>18</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-23 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>18</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-24 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>18</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# </location>
# <location wl_ver="3">
# <province>강원도영서</province>
# <city>춘천</city>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>16</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>16</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>17</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>17</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>17</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>17</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-22 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>19</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-23 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-24 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# </location>
# <location wl_ver="3">
# <province>강원도영서</province>
# <city>원주</city>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>16</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>16</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-22 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-23 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-24 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# </location>
# <location wl_ver="3">
# <province>강원도영동</province>
# <city>강릉</city>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>16</tmn>
# <tmx>25</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>16</tmn>
# <tmx>25</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>25</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>25</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>21</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>21</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-22 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-23 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-24 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# </location>
# <location wl_ver="3">
# <province>대전ㆍ세종ㆍ충청남도</province>
# <city>대전</city>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>17</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>17</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-22 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-23 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-24 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# </location>
# <location wl_ver="3">
# <province>대전ㆍ세종ㆍ충청남도</province>
# <city>세종</city>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>16</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>16</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>17</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>17</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>17</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>17</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-22 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-23 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-24 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# </location>
# <location wl_ver="3">
# <province>대전ㆍ세종ㆍ충청남도</province>
# <city>홍성</city>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>17</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>17</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-22 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-23 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-24 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# </location>
# <location wl_ver="3">
# <province>충청북도</province>
# <city>청주</city>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>17</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>17</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-22 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-23 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-24 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# </location>
# <location wl_ver="3">
# <province>광주ㆍ전라남도</province>
# <city>광주</city>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>19</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>19</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>31</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>31</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-22 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-23 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-24 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# </location>
# <location wl_ver="3">
# <province>광주ㆍ전라남도</province>
# <city>목포</city>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>19</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>19</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-22 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-23 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-24 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# </location>
# <location wl_ver="3">
# <province>광주ㆍ전라남도</province>
# <city>여수</city>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>19</tmn>
# <tmx>24</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>19</tmn>
# <tmx>24</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-22 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-23 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-24 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# </location>
# <location wl_ver="3">
# <province>전라북도</province>
# <city>전주</city>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>18</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>18</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-22 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-23 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-24 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# </location>
# <location wl_ver="3">
# <province>전라북도</province>
# <city>군산</city>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>18</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>18</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-22 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-23 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-24 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>19</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# </location>
# <location wl_ver="3">
# <province>부산ㆍ울산ㆍ경상남도</province>
# <city>부산</city>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>18</tmn>
# <tmx>25</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>18</tmn>
# <tmx>25</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>19</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>19</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-22 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>25</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-23 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-24 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# </location>
# <location wl_ver="3">
# <province>부산ㆍ울산ㆍ경상남도</province>
# <city>울산</city>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>16</tmn>
# <tmx>25</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>16</tmn>
# <tmx>25</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>18</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>18</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-22 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-23 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-24 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# </location>
# <location wl_ver="3">
# <province>부산ㆍ울산ㆍ경상남도</province>
# <city>창원</city>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>17</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>17</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>19</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>19</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>19</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-22 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-23 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-24 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# </location>
# <location wl_ver="3">
# <province>대구ㆍ경상북도</province>
# <city>대구</city>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>16</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>16</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>19</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>19</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>31</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>31</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-22 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-23 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-24 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# </location>
# <location wl_ver="3">
# <province>대구ㆍ경상북도</province>
# <city>안동</city>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>14</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>14</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>17</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>17</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>18</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>18</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-22 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>19</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-23 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>19</tmn>
# <tmx>30</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-24 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>19</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# </location>
# <location wl_ver="3">
# <province>대구ㆍ경상북도</province>
# <city>포항</city>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>16</tmn>
# <tmx>25</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>16</tmn>
# <tmx>25</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>18</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>20</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>21</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>21</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-22 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>29</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-23 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-24 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>28</tmx>
# <reliability>보통</reliability>
# </data>
# </location>
# <location wl_ver="3">
# <province>제주도</province>
# <city>제주</city>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>19</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>19</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>21</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>21</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-22 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-23 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-24 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# </location>
# <location wl_ver="3">
# <province>제주도</province>
# <city>서귀포</city>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-17 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>20</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-18 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>26</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-19 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 00:00</tmef>
# <wf>구름조금</wf>
# <tmn>21</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-21 12:00</tmef>
# <wf>구름조금</wf>
# <tmn>21</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-22 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-23 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2018-06-24 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>27</tmx>
# <reliability>보통</reliability>
# </data>
# </location>
# </body>
# </description>
# </item>
# </channel>
# </rss>

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://13.209.33.89:3333/quiz')
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')

# html 부분구조 가져오기
find_tag = bs.findAll("div")
print(find_tag)
# Out:
# [<div class="class_py_quiz" id="id_py_quiz">
# <h1>Python 퀴즈 </h1>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLScoGQuidGNCFerQZ6Dw5t6PndPPT62EvrncPLL3xLUfulRTyA/viewform?usp=sf_link"> 6/14 파이썬 데이터 불러오기/저장하기 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSftZ-2VYfHB46FrwFG2HjbRDBtLSO0XP2BmiHh3iqwGoi3pQQ/viewform?usp=sf_link"> 6/8 postgres 과제 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSeZBKjrZD1nAf4aAYhz_WEAqbzwPUPihgMEfXy74e0IMRwXKw/viewform?usp=sf_link"> 6/8 파이썬 제어문 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSdvFbZGNm7rSGQO_daDSWHC8o1BNgZtIBajLaiOcvgV2iV0IA/viewform?usp=sf_link"> 6/7 파이썬 자료형 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSehRuBYKpXNULxkamM8zVOd_mkFwZYwKtAp8Px0Kl0oCJbIeA/viewform?usp=sf_link"> 5/31 파이썬 머신러닝 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSeVt843wk9MBxLj0N84q_8Vg4yL1jTrOygA5Cm3z-asPDY1sg/viewform?usp=sf_link"> 5/24 파이썬 시작하기 </a>
# <p></p>
# </div>, <div class="class_sp_quiz" id="id_sp_quiz">
# <h1>Spark 퀴즈 </h1>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLScsDv_0mTFuJMqGfvrdjFAxVdeGOBpo8wOQSm5OiW1XcdBDFg/viewform?usp=sf_link"> 5/3 Spark 심화과정-groupby</a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSdNCn-NrLuFse4w2C36vqRPGUXtXDDsfLLxm-Sv9E7PwRwbrQ/viewform?usp=sf_link"> 4/27 Spark 심화과정 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSdfsGBmTFPfhZfFsKAOBOWx_x6f3mouhggIaYXbjW4EHbnBdA/viewform?usp=sf_link"> 4/12 Spark 기본과정 </a>
# <p></p>
# </div>, <div class="class_db_quiz" id="id_db_quiz">
# <h1>데이터베이스 퀴즈 </h1>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSff5TjqUq9u-jRxYZvTdB7k-N0AEjx0_WSIcLZCBfFiEfoRUA/viewform?usp=sf_link"> 6/12 오라클 Join 퀴즈 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLScP3ojzBNFbKbTFq4r58GqqZODYom1d6jrn09rmdqT57uByVA/viewform?usp=sf_link"> 6/5 오라클 GroupBy 퀴즈 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSfU5Pv_GQOLV-SkrDirOGt4GLDP3sZpy-UPY4zsud2ODPknbA/viewform?usp=sf_link"> 5/29 오라클 숫자/날짜 및 고급함수 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSdFuYrwaYE6HEzQft21Icj_2yPyQqkcSabuvnaWwO47v99XmA/viewform?usp=sf_link"> 5/15 오라클 데이터 조회(함수활용)  </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSd8MAsXIKIteOM4OFCggUoYeOqC5aGI-2aQFLV8533HkbTz-w/viewform?usp=sf_link"> 5/8 오라클 원격접속 및 조회 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSeYl0KM70XWhjnTIVLfqX5H5tp2V3jx2bwJMyZrTSeak2HZWw/viewform?usp=sf_link"> 4/10 무결성 제약조건 </a>
# </div>]

# %%
resp.status_code
# Out:
# 200

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://13.209.33.89:3333/quiz')
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')

# html 부분구조 가져오기
find_tag = bs.findAll("div")
print(find_tag)
# Out:
# [<div class="class_py_quiz" id="id_py_quiz">
# <h1>Python 퀴즈 </h1>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSftZ-2VYfHB46FrwFG2HjbRDBtLSO0XP2BmiHh3iqwGoi3pQQ/viewform?usp=sf_link"> 6/8 postgres 과제 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSeZBKjrZD1nAf4aAYhz_WEAqbzwPUPihgMEfXy74e0IMRwXKw/viewform?usp=sf_link"> 6/8 파이썬 제어문 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSdvFbZGNm7rSGQO_daDSWHC8o1BNgZtIBajLaiOcvgV2iV0IA/viewform?usp=sf_link"> 6/7 파이썬 자료형 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSehRuBYKpXNULxkamM8zVOd_mkFwZYwKtAp8Px0Kl0oCJbIeA/viewform?usp=sf_link"> 5/31 파이썬 머신러닝 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSeVt843wk9MBxLj0N84q_8Vg4yL1jTrOygA5Cm3z-asPDY1sg/viewform?usp=sf_link"> 5/24 파이썬 시작하기 </a>
# <p></p>
# </div>, <div class="class_sp_quiz" id="id_sp_quiz">
# <h1>Spark 퀴즈 </h1>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLScsDv_0mTFuJMqGfvrdjFAxVdeGOBpo8wOQSm5OiW1XcdBDFg/viewform?usp=sf_link"> 5/3 Spark 심화과정-groupby</a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSdNCn-NrLuFse4w2C36vqRPGUXtXDDsfLLxm-Sv9E7PwRwbrQ/viewform?usp=sf_link"> 4/27 Spark 심화과정 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSdfsGBmTFPfhZfFsKAOBOWx_x6f3mouhggIaYXbjW4EHbnBdA/viewform?usp=sf_link"> 4/12 Spark 기본과정 </a>
# <p></p>
# </div>, <div class="class_db_quiz" id="id_db_quiz">
# <h1>데이터베이스 퀴즈 </h1>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSff5TjqUq9u-jRxYZvTdB7k-N0AEjx0_WSIcLZCBfFiEfoRUA/viewform?usp=sf_link"> 6/12 오라클 Join 퀴즈 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLScP3ojzBNFbKbTFq4r58GqqZODYom1d6jrn09rmdqT57uByVA/viewform?usp=sf_link"> 6/5 오라클 GroupBy 퀴즈 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSfU5Pv_GQOLV-SkrDirOGt4GLDP3sZpy-UPY4zsud2ODPknbA/viewform?usp=sf_link"> 5/29 오라클 숫자/날짜 및 고급함수 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSdFuYrwaYE6HEzQft21Icj_2yPyQqkcSabuvnaWwO47v99XmA/viewform?usp=sf_link"> 5/15 오라클 데이터 조회(함수활용)  </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSd8MAsXIKIteOM4OFCggUoYeOqC5aGI-2aQFLV8533HkbTz-w/viewform?usp=sf_link"> 5/8 오라클 원격접속 및 조회 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSeYl0KM70XWhjnTIVLfqX5H5tp2V3jx2bwJMyZrTSeak2HZWw/viewform?usp=sf_link"> 4/10 무결성 제약조건 </a>
# </div>]

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://13.209.33.89:3333/quiz')
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')

# html 태그 속성으로 찾기
find_attr = bs.find("div",{"class":"class_db_quiz"})
print(find_attr)
# Out:
# <div class="class_db_quiz" id="id_db_quiz">
# <h1>데이터베이스 퀴즈 </h1>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSff5TjqUq9u-jRxYZvTdB7k-N0AEjx0_WSIcLZCBfFiEfoRUA/viewform?usp=sf_link"> 6/12 오라클 Join 퀴즈 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLScP3ojzBNFbKbTFq4r58GqqZODYom1d6jrn09rmdqT57uByVA/viewform?usp=sf_link"> 6/5 오라클 GroupBy 퀴즈 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSfU5Pv_GQOLV-SkrDirOGt4GLDP3sZpy-UPY4zsud2ODPknbA/viewform?usp=sf_link"> 5/29 오라클 숫자/날짜 및 고급함수 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSdFuYrwaYE6HEzQft21Icj_2yPyQqkcSabuvnaWwO47v99XmA/viewform?usp=sf_link"> 5/15 오라클 데이터 조회(함수활용)  </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSd8MAsXIKIteOM4OFCggUoYeOqC5aGI-2aQFLV8533HkbTz-w/viewform?usp=sf_link"> 5/8 오라클 원격접속 및 조회 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSeYl0KM70XWhjnTIVLfqX5H5tp2V3jx2bwJMyZrTSeak2HZWw/viewform?usp=sf_link"> 4/10 무결성 제약조건 </a>
# </div>

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://13.209.33.89:3333/quiz')
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')

# html 부분구조 가져오기
find_tag = bs.find("div")
print(find_tag)
# Out:
# <div class="class_py_quiz" id="id_py_quiz">
# <h1>Python 퀴즈 </h1>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSftZ-2VYfHB46FrwFG2HjbRDBtLSO0XP2BmiHh3iqwGoi3pQQ/viewform?usp=sf_link"> 6/8 postgres 과제 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSeZBKjrZD1nAf4aAYhz_WEAqbzwPUPihgMEfXy74e0IMRwXKw/viewform?usp=sf_link"> 6/8 파이썬 제어문 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSdvFbZGNm7rSGQO_daDSWHC8o1BNgZtIBajLaiOcvgV2iV0IA/viewform?usp=sf_link"> 6/7 파이썬 자료형 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSehRuBYKpXNULxkamM8zVOd_mkFwZYwKtAp8Px0Kl0oCJbIeA/viewform?usp=sf_link"> 5/31 파이썬 머신러닝 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSeVt843wk9MBxLj0N84q_8Vg4yL1jTrOygA5Cm3z-asPDY1sg/viewform?usp=sf_link"> 5/24 파이썬 시작하기 </a>
# <p></p>
# </div>

# %% [markdown]
# ### 2. 속성 찾기 - find

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://13.209.33.89:3333/quiz')
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')

# html 태그 속성으로 찾기
find_attr = bs.find("div",{"id":"id_db_quiz"})
print(find_attr)
# Out:
# <div class="class_db_quiz" id="id_db_quiz">
# <h1>데이터베이스 퀴즈 </h1>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLScP3ojzBNFbKbTFq4r58GqqZODYom1d6jrn09rmdqT57uByVA/viewform?usp=sf_link"> 6/5 오라클 GroupBy 퀴즈 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSfU5Pv_GQOLV-SkrDirOGt4GLDP3sZpy-UPY4zsud2ODPknbA/viewform?usp=sf_link"> 5/29 오라클 숫자/날짜 및 고급함수 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSdFuYrwaYE6HEzQft21Icj_2yPyQqkcSabuvnaWwO47v99XmA/viewform?usp=sf_link"> 5/15 오라클 데이터 조회(함수활용)  </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSd8MAsXIKIteOM4OFCggUoYeOqC5aGI-2aQFLV8533HkbTz-w/viewform?usp=sf_link"> 5/8 오라클 원격접속 및 조회 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSeYl0KM70XWhjnTIVLfqX5H5tp2V3jx2bwJMyZrTSeak2HZWw/viewform?usp=sf_link"> 4/10 무결성 제약조건 </a>
# </div>

# %% [markdown]
# ### 3. 태그내 dom 부분구조 찾기

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://13.209.33.89:3333/quiz')
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')

# html 부분구조 가져오기
find_attr = bs.find("div",{"id":"id_db_quiz"})
find_part = find_attr.find("a")
print(find_part)
# Out:
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSff5TjqUq9u-jRxYZvTdB7k-N0AEjx0_WSIcLZCBfFiEfoRUA/viewform?usp=sf_link"> 6/12 오라클 Join 퀴즈 </a>

# %% [markdown]
# ### 4. DOM 구조 내 속성 찾기

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://13.209.33.89:3333/quiz')
resp.encoding='utf-8'
html = resp.text
bs = bs4.BeautifulSoup(html, 'html.parser')
# html 부분구조 가져오기
find_part = bs.find("div",{"id":"id_db_quiz"})
# 링크내 속성 가져오기
link = find_part.find("a")
print(find_part.find("a").attrs['href'])
# Out:
# https://docs.google.com/forms/d/e/1FAIpQLSff5TjqUq9u-jRxYZvTdB7k-N0AEjx0_WSIcLZCBfFiEfoRUA/viewform?usp=sf_link

# %% [markdown]
# ### 실습 링크 속성 추출하기

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://13.209.33.89:3333/quiz')
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')

# html 부분구조 가져오기
a_links = bs.findAll("a")
for a in a_links:
    href= a.attrs["href"]
    print(href)
# Out:
# /
# /quiz
# /maps/add
# /maps
# /maps/geomap
# /maps/chart
# /maps/chartLine
# /maps/gitList
# /test
# https://docs.google.com/forms/d/e/1FAIpQLScoGQuidGNCFerQZ6Dw5t6PndPPT62EvrncPLL3xLUfulRTyA/viewform?usp=sf_link
# https://docs.google.com/forms/d/e/1FAIpQLSftZ-2VYfHB46FrwFG2HjbRDBtLSO0XP2BmiHh3iqwGoi3pQQ/viewform?usp=sf_link
# https://docs.google.com/forms/d/e/1FAIpQLSeZBKjrZD1nAf4aAYhz_WEAqbzwPUPihgMEfXy74e0IMRwXKw/viewform?usp=sf_link
# https://docs.google.com/forms/d/e/1FAIpQLSdvFbZGNm7rSGQO_daDSWHC8o1BNgZtIBajLaiOcvgV2iV0IA/viewform?usp=sf_link
# https://docs.google.com/forms/d/e/1FAIpQLSehRuBYKpXNULxkamM8zVOd_mkFwZYwKtAp8Px0Kl0oCJbIeA/viewform?usp=sf_link
# https://docs.google.com/forms/d/e/1FAIpQLSeVt843wk9MBxLj0N84q_8Vg4yL1jTrOygA5Cm3z-asPDY1sg/viewform?usp=sf_link
# https://docs.google.com/forms/d/e/1FAIpQLScsDv_0mTFuJMqGfvrdjFAxVdeGOBpo8wOQSm5OiW1XcdBDFg/viewform?usp=sf_link
# https://docs.google.com/forms/d/e/1FAIpQLSdNCn-NrLuFse4w2C36vqRPGUXtXDDsfLLxm-Sv9E7PwRwbrQ/viewform?usp=sf_link
# https://docs.google.com/forms/d/e/1FAIpQLSdfsGBmTFPfhZfFsKAOBOWx_x6f3mouhggIaYXbjW4EHbnBdA/viewform?usp=sf_link
# https://docs.google.com/forms/d/e/1FAIpQLSff5TjqUq9u-jRxYZvTdB7k-N0AEjx0_WSIcLZCBfFiEfoRUA/viewform?usp=sf_link
# https://docs.google.com/forms/d/e/1FAIpQLScP3ojzBNFbKbTFq4r58GqqZODYom1d6jrn09rmdqT57uByVA/viewform?usp=sf_link
# https://docs.google.com/forms/d/e/1FAIpQLSfU5Pv_GQOLV-SkrDirOGt4GLDP3sZpy-UPY4zsud2ODPknbA/viewform?usp=sf_link
# https://docs.google.com/forms/d/e/1FAIpQLSdFuYrwaYE6HEzQft21Icj_2yPyQqkcSabuvnaWwO47v99XmA/viewform?usp=sf_link
# https://docs.google.com/forms/d/e/1FAIpQLSd8MAsXIKIteOM4OFCggUoYeOqC5aGI-2aQFLV8533HkbTz-w/viewform?usp=sf_link
# https://docs.google.com/forms/d/e/1FAIpQLSeYl0KM70XWhjnTIVLfqX5H5tp2V3jx2bwJMyZrTSeak2HZWw/viewform?usp=sf_link

# %%
 href= a.attrs["href"]
    print(href)

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://13.209.33.89:3333/quiz')
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')

# html 부분구조 가져오기
a_links = bs.findAll("a")
for a in a_links:
    #a 링크 내 href 속성
    href=a.attrs["href"]
    #a 링크 텍스트
    text = a.text
    if(href.startswith("/")):
        continue;
    print(text, ">", href)
# Out:
#  6/14 파이썬 데이터 불러오기/저장하기  > https://docs.google.com/forms/d/e/1FAIpQLScoGQuidGNCFerQZ6Dw5t6PndPPT62EvrncPLL3xLUfulRTyA/viewform?usp=sf_link
#  6/8 postgres 과제  > https://docs.google.com/forms/d/e/1FAIpQLSftZ-2VYfHB46FrwFG2HjbRDBtLSO0XP2BmiHh3iqwGoi3pQQ/viewform?usp=sf_link
#  6/8 파이썬 제어문  > https://docs.google.com/forms/d/e/1FAIpQLSeZBKjrZD1nAf4aAYhz_WEAqbzwPUPihgMEfXy74e0IMRwXKw/viewform?usp=sf_link
#  6/7 파이썬 자료형  > https://docs.google.com/forms/d/e/1FAIpQLSdvFbZGNm7rSGQO_daDSWHC8o1BNgZtIBajLaiOcvgV2iV0IA/viewform?usp=sf_link
#  5/31 파이썬 머신러닝  > https://docs.google.com/forms/d/e/1FAIpQLSehRuBYKpXNULxkamM8zVOd_mkFwZYwKtAp8Px0Kl0oCJbIeA/viewform?usp=sf_link
#  5/24 파이썬 시작하기  > https://docs.google.com/forms/d/e/1FAIpQLSeVt843wk9MBxLj0N84q_8Vg4yL1jTrOygA5Cm3z-asPDY1sg/viewform?usp=sf_link
#  5/3 Spark 심화과정-groupby > https://docs.google.com/forms/d/e/1FAIpQLScsDv_0mTFuJMqGfvrdjFAxVdeGOBpo8wOQSm5OiW1XcdBDFg/viewform?usp=sf_link
#  4/27 Spark 심화과정  > https://docs.google.com/forms/d/e/1FAIpQLSdNCn-NrLuFse4w2C36vqRPGUXtXDDsfLLxm-Sv9E7PwRwbrQ/viewform?usp=sf_link
#  4/12 Spark 기본과정  > https://docs.google.com/forms/d/e/1FAIpQLSdfsGBmTFPfhZfFsKAOBOWx_x6f3mouhggIaYXbjW4EHbnBdA/viewform?usp=sf_link
#  6/12 오라클 Join 퀴즈  > https://docs.google.com/forms/d/e/1FAIpQLSff5TjqUq9u-jRxYZvTdB7k-N0AEjx0_WSIcLZCBfFiEfoRUA/viewform?usp=sf_link
#  6/5 오라클 GroupBy 퀴즈  > https://docs.google.com/forms/d/e/1FAIpQLScP3ojzBNFbKbTFq4r58GqqZODYom1d6jrn09rmdqT57uByVA/viewform?usp=sf_link
#  5/29 오라클 숫자/날짜 및 고급함수  > https://docs.google.com/forms/d/e/1FAIpQLSfU5Pv_GQOLV-SkrDirOGt4GLDP3sZpy-UPY4zsud2ODPknbA/viewform?usp=sf_link
#  5/15 오라클 데이터 조회(함수활용)   > https://docs.google.com/forms/d/e/1FAIpQLSdFuYrwaYE6HEzQft21Icj_2yPyQqkcSabuvnaWwO47v99XmA/viewform?usp=sf_link
#  5/8 오라클 원격접속 및 조회  > https://docs.google.com/forms/d/e/1FAIpQLSd8MAsXIKIteOM4OFCggUoYeOqC5aGI-2aQFLV8533HkbTz-w/viewform?usp=sf_link
#  4/10 무결성 제약조건  > https://docs.google.com/forms/d/e/1FAIpQLSeYl0KM70XWhjnTIVLfqX5H5tp2V3jx2bwJMyZrTSeak2HZWw/viewform?usp=sf_link

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get("http://finance.naver.com/marketindex/")
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')

# 데이터 추출하기
price = bs.select_one("div.head_info > span.value").string
print("usd/krw= ", price)

# 리스트 초기화 및 데이터 담기
outList = []
outList.append(price)

# 리스트 pandas 데이터 프레임으로 변환 및 컬럼 정의
outDf = pd.DataFrame(np.array(outList).reshape(1,1))
outDf.columns = ['title']
# CSV 파일로 저장, encondig 한글깨짐 방지
#outDf.to_csv("../dataset/webData.csv", encoding='utf-8-sig',index=False)
outDf
# Out:
# usd/krw=  1,083.00
#       title
# 0  1,083.00

# %% [markdown]
# ### 테이블

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://13.209.33.89:3333/maps')
resp.encoding='utf-8'
html = resp.text
bs = bs4.BeautifulSoup(html, 'html.parser')
# html 부분구조 가져오기
columns=bs.select('table > thead > tr > th')
columns
type(columns)
# Out:
# list

# %%
columnlist=[]
for column in columns:
    columnlist.append(column.text)
df=pd.DataFrame(columns=columnlist)
df
# Out:
# Empty DataFrame
# Columns: [geo_name, longitude, latitude, Action]
# Index: []

# %%
contents=bs.select('table  > tbody > tr#trbody')
contents
# Out:
# [<tr id="trbody">
#  <td>polytech_kangseo2</td>
#  <td>126.840918</td>
#  <td>37.549506</td>
#  <td>
#  <div style="float:left">
#  <a href="/maps/edit/6">Edit</a>
#                      <form action="/maps/delete/6" method="post" style="float:right">
#  <input name="delete" onclick="return confirm('Are you sure you want to delete?')" type="submit" value="Delete"/>
#  <input name="_method" type="hidden" value="DELETE"/>
#  </form>
#  </div>
#  </td>
#  </tr>, <tr id="trbody">
#  <td>coffeekorea_seulleng</td>
#  <td>127.0478832</td>
#  <td>37.50567504</td>
#  <td>
#  <div style="float:left">
#  <a href="/maps/edit/5">Edit</a>
#                      <form action="/maps/delete/5" method="post" style="float:right">
#  <input name="delete" onclick="return confirm('Are you sure you want to delete?')" type="submit" value="Delete"/>
#  <input name="_method" type="hidden" value="DELETE"/>
#  </form>
#  </div>
#  </td>
#  </tr>]

# %%
contents=bs.select('table  > tbody > tr#trbody')
dfcontent=[]
alldfcontents=[]

for content in contents:
    tds=content.findAll("td")
    for td in tds:
        if(td.text=="None"):
            continue;
        dfcontent.append(td.text)
    alldfcontents.append(dfcontent)
    dfcontent=[]
df=pd.DataFrame(data=alldfcontents)
df

#columns=columnlist,
# Out:
#                       0            1            2  \
# 0     polytech_kangseo2   126.840918    37.549506
# 1  coffeekorea_seulleng  127.0478832  37.50567504
#
#                                                    3
# 0  \n\nEdit                              \n      ...
# 1  \n\nEdit                              \n      ...

# %%
df.columns = ['aa','bb','cc','dd']
df
# Out:
#                      aa           bb           cc  \
# 0     polytech_kangseo2   126.840918    37.549506
# 1  coffeekorea_seulleng  127.0478832  37.50567504
#
#                                                   dd
# 0  \n\nEdit                              \n      ...
# 1  \n\nEdit                              \n      ...

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://13.209.33.89:3333/maps')
resp.encoding='utf-8'
html = resp.text
bs = bs4.BeautifulSoup(html, 'html.parser')

# html 부분구조 가져오기
columns=soup.select('table  > tr > th')
columns
# Out:
# [<th>geo_name</th>, <th>longitude</th>, <th>latitude</th>, <th>Action</th>]

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://13.209.33.89:3333/maps')
resp.encoding='utf-8'
html = resp.text
bs = bs4.BeautifulSoup(html, 'html.parser')

# html 부분구조 가져오기
columns=soup.select('table > tr > th')
columns

columnlist=[]
for column in columns:
    columnlist.append(column.text)
df=pd.DataFrame(columns=columnlist)

df
# Out:
# Empty DataFrame
# Columns: [geo_name, longitude, latitude, Action]
# Index: []

# %%
contents=bs.select('table  > tbody > tr#trbody')
dfcontent=[]
alldfcontents=[]

for content in contents:
    tds=content.findAll("td")
    for td in tds:
        if(td.text=="None"):
            continue;
        dfcontent.append(td.text)
    alldfcontents.append(dfcontent)
    dfcontent=[]
df=pd.DataFrame(columns=columnlist, data=alldfcontents)
df
# Out:
#                geo_name    longitude     latitude  \
# 0     polytech_kangseo2   126.840918    37.549506
# 1  coffeekorea_seulleng  127.0478832  37.50567504
#
#                                               Action
# 0  \n\nEdit                              \n      ...
# 1  \n\nEdit                              \n      ...

# %%
df.to

# %%
contents=bs.select('table > tbody > tr')
dfcontent=[]
alldfcontents=[]

for content in contents:
    tds=content.findAll("td")
    for td in tds:
        if(td.text=="None"):
            continue;
        dfcontent.append(td.text)
    alldfcontents.append(dfcontent)
    dfcontent=[]
df=pd.DataFrame(columns=columnlist, data=alldfcontents)
df
# Out:
#                geo_name    longitude     latitude  \
# 0     polytech_kangseo2   126.840918    37.549506
# 1  coffeekorea_seulleng  127.0478832  37.50567504
#
#                                               Action
# 0  \n\nEdit                              \n      ...
# 1  \n\nEdit                              \n      ...

# %%
contents=bs.findAll("tr", {"id":"trbody"})
dfcontent=[]
alldfcontents=[]

for content in contents:
    tds=content.findAll("td")
    for td in tds:
        if(td.text=="None"):
            continue;
        dfcontent.append(td.text)
    alldfcontents.append(dfcontent)
    dfcontent=[]
df=pd.DataFrame(columns=columnlist, data=alldfcontents)
df
# Out:
#                geo_name    longitude     latitude  \
# 0     polytech_kangseo2   126.840918    37.549506
# 1  coffeekorea_seulleng  127.0478832  37.50567504
#
#                                               Action
# 0  \n\nEdit                              \n      ...
# 1  \n\nEdit                              \n      ...

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://13.209.33.89:3333/maps/gitList')
resp.encoding='utf-8'
html = resp.text
bs = bs4.BeautifulSoup(html, 'html.parser')

# html 부분구조 가져오기
columns=bs.select('table > tr > th')

gitColumnlist=[]
for column in columns:
    gitColumnlist.append(column.text)
df=pd.DataFrame(columns=gitColumnlist)
df
# Out:
# Empty DataFrame
# Columns: [순번, 학생 이름, GIT 주소(뒷부분), 수정]
# Index: []

# %%
contents=bs.select('table > tr#gitContents')
dfcontent=[]
alldfcontents=[]

for content in contents:
    tds=content.findAll("td")
    for td in tds:
        dfcontent.append(td.text)
    alldfcontents.append(dfcontent)
    dfcontent=[]
df=pd.DataFrame(columns=gitColumnlist, data=alldfcontents, index=None)
df.columns=["no","std_name","git_address","edit"]
finalDf = df[["no","std_name","git_address"]]
print(finalDf.head())
finalDf.columns=["안녕","안녕2","안녕3"]
finalDf.to_csv("d:/git_address.csv",index=False, encoding="utf-8-sig")
finalDf
# Out:
#   no        std_name git_address
# 0  1  KIM GANG RYONG      wovmxl
# 1  2     KIM DO WOON   dowoonkim
# 2  3     KIM EUI JIN       doogn
# 3  4   NOH YOUNG WOO   ppoocoder
# 4  5  PARK SEUNG JIN      tmdwls
#     안녕             안녕2            안녕3
# 0    1  KIM GANG RYONG         wovmxl
# 1    2     KIM DO WOON      dowoonkim
# 2    3     KIM EUI JIN          doogn
# 3    4   NOH YOUNG WOO      ppoocoder
# 4    5  PARK SEUNG JIN         tmdwls
# 5    6    SUNG HAN BIN     sunghanbin
# 6    7   SHIN SUNG WOO      sinletsgo
# 7    8       OH MI JIN        ohmijin
# 8    9   LEE DONG GEUN          awd45
# 9   10    LEE WOO SEOK        creed35
# 10  11     LEE EUN SIL    milklandcoo
# 11  12     LEE HAN MIN         yumras
# 12  13     LEE HYO JAE        freespa
# 13  14  JUNG KYUNG HWA       JungKH89
# 14  15  JEONG YU SEOCK    jeongyuseoc
# 15  16    JUNG HYO JAE      jamiewell
# 16  17   CHO DONG YEOK       jody0406
# 17  18   JO JEONG YEON          hera7
# 18  19   CHAE SUNG EUN     sechae0528
# 19  20  CHOI KYUNG JAE        ckt9636
# 20  21   CHOI DONG HUN    MakeBelieve
# 21  22   CHOI MIN SUNG       sakurac0
# 22  23     HA TAE YANG      hataeyang
# 23  24    YOON SUNG HO     youtoo1116
# 24  25     KIM JI SUNG       binggugu
# 25  26    CHOI MIN HAN  do not submit

# %%
tds2=content.findAll("td")
tds2
# Out:
# [<td>coffeekorea_seulleng</td>,
#  <td>127.0478832</td>,
#  <td>37.50567504</td>,
#  <td>
#  <div style="float:left">
#  <a href="/maps/edit/5">Edit</a>
#                      <form action="/maps/delete/5" method="post" style="float:right">
#  <input name="delete" onclick="return confirm('Are you sure you want to delete?')" type="submit" value="Delete"/>
#  <input name="_method" type="hidden" value="DELETE"/>
#  </form>
#  </div>
#  </td>]

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get("http://finance.naver.com/marketindex/")
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')

# 데이터 추출하기
price = bs.select_one("div.head_info > span.value").string
print("usd/krw= ", price)

# 리스트 초기화 및 데이터 담기
outList = []
outList.append(price)

# 리스트 pandas 데이터 프레임으로 변환 및 컬럼 정의
outDf = pd.DataFrame(np.array(outList).reshape(1,1))
outDf.columns = ['title']
# CSV 파일로 저장, encondig 한글깨짐 방지
#outDf.to_csv("../dataset/webData.csv", encoding='utf-8-sig',index=False)
outDf
# Out:
# usd/krw=  1,069.50
#       title
# 0  1,069.50

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://13.209.33.89:3333/quiz')
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, "html.parser")

# div에서 id가 id_db_quiz인것만 추출
seone = bs.select_one("div.class_db_quiz > a").string
print(seone)
    
# div에서 id가 id_db_quiz인것만 추출
divs = bs.select("div.class_db_quiz > a")
for li in divs:
    print(li.string)
# Out:
#  6/5 오라클 GroupBy 퀴즈
#  6/5 오라클 GroupBy 퀴즈
#  5/29 오라클 숫자/날짜 및 고급함수
#  5/15 오라클 데이터 조회(함수활용)
#  5/8 오라클 원격접속 및 조회
#  4/10 무결성 제약조건

# %%
h1 = bs.html.body.p
print(h1)
# Out:
# <p></p>

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://13.209.33.89:3333/quiz')
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')

# html 부분구조 가져오기
find_part = bs.find("div",{"id":"id_db_quiz"})

# 링크내 속성 가져오기
for link in find_part.findAll("a"):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# https://docs.google.com/forms/d/e/1FAIpQLScP3ojzBNFbKbTFq4r58GqqZODYom1d6jrn09rmdqT57uByVA/viewform?usp=sf_link
# https://docs.google.com/forms/d/e/1FAIpQLSfU5Pv_GQOLV-SkrDirOGt4GLDP3sZpy-UPY4zsud2ODPknbA/viewform?usp=sf_link
# https://docs.google.com/forms/d/e/1FAIpQLSdFuYrwaYE6HEzQft21Icj_2yPyQqkcSabuvnaWwO47v99XmA/viewform?usp=sf_link
# https://docs.google.com/forms/d/e/1FAIpQLSd8MAsXIKIteOM4OFCggUoYeOqC5aGI-2aQFLV8533HkbTz-w/viewform?usp=sf_link
# https://docs.google.com/forms/d/e/1FAIpQLSeYl0KM70XWhjnTIVLfqX5H5tp2V3jx2bwJMyZrTSeak2HZWw/viewform?usp=sf_link

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://13.209.33.89:3333/quiz')
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')

# html 부분구조 가져오기
find_part = bs.find("div",{"id":"id_db_quiz"})

# 링크내 속성 가져오기
link = find_part.find("a")
print(find_part.find("a").attrs['href'])
# Out:
# https://docs.google.com/forms/d/e/1FAIpQLScP3ojzBNFbKbTFq4r58GqqZODYom1d6jrn09rmdqT57uByVA/viewform?usp=sf_link

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://finance.daum.net/quote/marketvalue.daum')
#resp.encoding='utf-8-sig'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')

stock_list = bs.select("#myListTop1 > li")
#stock_list = bs.find("ul",{"id":"myListTop1"}).findAll("li")
#stock_list[0].find('a').text
count = 0
stock_nameList = []
stock_priceList = []
stock_main_no = 6
for stock_one in stock_list:
    if count > stock_main_no:
        break
    stock_name = stock_one.find('a').text
    stock_price = stock_one.find("span",{"class":"cost num"}).text
    stock_nameList.append(stock_name)
    stock_priceList.append(stock_price)
    count += 1
    #print(count, stock_name, stock_price,count)
list1 = pd.DataFrame(stock_nameList)
list2 = pd.DataFrame(stock_priceList)
final = pd.concat([list1,list2], axis = 1)
final.columns=['STOCK_NAME','STOCK_PRICE']
final
# Out:
#    STOCK_NAME STOCK_PRICE
# 0        삼성전자      48,500
# 1      SK하이닉스      87,300
# 2        셀트리온     284,500
# 3       삼성전자우      38,650
# 4       POSCO     364,500
# 5         현대차     135,500
# 6   삼성바이오로직..     409,000

# %%
import pandas as pd
from sqlalchemy import create_engine 
 
# DB 커넥션 열기
engine = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl') 


# 데이터 저장
tablename = "KOPO_STOCK_ST_김효관"
final.to_sql(tablename, engine, if_exists='replace', index=False)

# %%
import requests, bs4, pandas as pd, numpy as np   #웹페이지 html 소스 가져오기 resp = requests.get('http://finance.daum.net/quote/marketvalue.daum') resp.encoding='utf-8' html = resp.text bs = bs4.BeautifulSoup(html, 'html.parser')  # html 부분구조 가져오기 # html 부분구조 가져오기 find_part = bs.find("tr",{"onmouseout":"highlight(this,false)"}) # 링크내 속성 가져오기 link = find_part.find("a") link columns=bs.select('table > tr > th') # 순서대로 타고 들어가기  columns  columnlist=[] for column in columns:     columnlist.append(column.text) df=pd.DataFrame(columns=columnlist) df contents1=bs.findAll("tr",{"onmouseout":"highlight(this,false)"}) contents1 dfcontent=[] alldfcontents=[] for content in contents1:     tds=content.findAll("td")     for td in tds:         if(td.text=="None"):             continue;         dfcontent.append(td.text)     alldfcontents.append(dfcontent)     dfcontent=[] df=pd.DataFrame(columns=columnlist, data=alldfcontents, index=None)  df.columns=["순위", "종목명","현재가", "전일비","등락률", "시가총액", "상장주식수", "외국인비율"] finalDf = df[["순위", "종목명", "현재가"]] print(finalDf) # CSV 파일로 저장, encondig 한글깨짐 방지 finalDf.to_csv("../dataset/finalDF.csv", encoding='utf-8-sig',index=False)

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://finance.daum.net/quote/marketvalue.daum')
resp.encoding='utf-8'
html = resp.text
bs = bs4.BeautifulSoup(html, 'html.parser')

# html 부분구조 가져오기
# html 부분구조 가져오기
find_part = bs.find("tr",{"onmouseout":"highlight(this,false)"})
# 링크내 속성 가져오기
link = find_part.find("a")
link
columns=bs.select('table > tr > th') # 순서대로 타고 들어가기 
columns

columnlist=[]
for column in columns:
    columnlist.append(column.text)
df=pd.DataFrame(columns=columnlist)
df
contents1=bs.findAll("tr",{"onmouseout":"highlight(this,false)"})
contents1
dfcontent=[]
alldfcontents=[]
for content in contents1:
    tds=content.findAll("td")
    for td in tds:
        if(td.text=="None"):
            continue;
        dfcontent.append(td.text)
    alldfcontents.append(dfcontent)
    dfcontent=[]
df=pd.DataFrame(columns=columnlist, data=alldfcontents, index=None)

df.columns=["순위", "종목명","현재가", "전일비","등락률", "시가총액", "상장주식수", "외국인비율"]
finalDf = df[["순위", "종목명", "현재가"]]
finalDf
# Out:
#     순위       종목명        현재가
# 0    1      삼성전자     48,300
# 1    2    SK하이닉스     87,100
# 2    3      셀트리온    288,500
# 3    4     삼성전자우     38,450
# 4    5     POSCO    365,500
# 5    6       현대차    136,000
# 6    7  삼성바이오로직스    413,500
# 7    8      LG화학    377,000
# 8    9      삼성물산    123,000
# 9   10     NAVER    693,000
# 10  11    LG생활건강  1,456,000
# 11  12      한국전력     35,300
# 12  13      KB금융     54,000
# 13  14     현대모비스    221,000
# 14  15      신한지주     45,300
# 15  16      삼성생명    102,500
# 16  17   SK이노베이션    214,000
# 17  18     SK텔레콤    241,000
# 18  19        SK    270,500
# 19  20    아모레퍼시픽    316,000
# 20  21     삼성SDI    234,000
# 21  22   삼성에스디에스    206,500
# 22  23      LG전자     93,300
# 23  24     KT&G;    101,000
# 24  25    하나금융지주     43,850
# 25  26       기아차     32,400
# 26  27        LG     75,300
# 27  28       넷마블    150,500
# 28  29     롯데케미칼    362,500
# 29  30     S-Oil    109,000

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://finance.daum.net/quote/marketvalue.daum')
#resp.encoding='utf-8-sig'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')
stock_list = bs.find("ul",{"id":"myListTop1"}).findAll("li")
stock_list

count = 0
stock_nameList = []
stock_priceList = []
stock_num = 6
#for stock_one in stock_list:
for stock_one in stock_list:
    if count > stock_num:
        break
    stock_name = stock_one.find('a').text
    stock_price = float(stock_one.find("span",{"class":"cost num"}).text.replace(",",""))
    stock_nameList.append(stock_name)
    stock_priceList.append(stock_price)
    count += 1
list1 = pd.DataFrame(stock_nameList, dtype=str)
stock_priceList
list2 = pd.DataFrame(stock_priceList, dtype=float)
final = pd.concat([list1,list2], axis = 1)
final.columns=['STOCK_NAME','STOCK_PRICE']
final
#float(stock_list[0].find("span",{"class":"cost num"}).text.replace(",",""))
#stock_price = float(stock_one.find("span",{"class":"cost num"}).text.replace(",",""))
# stock_nameList.append(stock_name)
# stock_priceList.append(stock_price)
# count += 1
# Out:
#    STOCK_NAME  STOCK_PRICE
# 0        삼성전자      48100.0
# 1      SK하이닉스      86500.0
# 2        셀트리온     293000.0
# 3       삼성전자우      38200.0
# 4       POSCO     366000.0
# 5         현대차     135500.0
# 6   삼성바이오로직..     409500.0

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://finance.daum.net/quote/marketvalue.daum')
resp.encoding='utf-8'
html = resp.text
bs = bs4.BeautifulSoup(html, 'html.parser')

# html 부분구조 가져오기
# html 부분구조 가져오기
columns=bs.select('table > tr > th') # 순서대로 타고 들어가기 
columns

columnlist=[]
for column in columns:
    columnlist.append(column.text)
df=pd.DataFrame(columns=columnlist)
df
contents1=bs.findAll("tr".{"onmouseout":"highlight(this,false)"}. limit=7)
contents1
dfcontent=[]
alldfcontents=[]
for content in contents1:
    tds=content.findAll("td")
    for td in tds:
        if(td.text=="None"):
            continue;
        dfcontent.append(td.text)
    alldfcontents.append(dfcontent)
    dfcontent=[]
df=pd.DataFrame(columns=columnlist, data=alldfcontents, index=None)

df.columns=["순위", "종목명","현재가", "전일비","등락률", "시가총액", "상장주식수", "외국인비율"]
finalDf = df[["순위", "종목명", "현재가"]]
print(finalDf)
# CSV 파일로 저장, encondig 한글깨짐 방지
#finalDf.to_csv("../dataset/finalDF.csv", encoding='utf-8-sig',index=False)
# Out:
#   File "<ipython-input-84-4bb61a4af8bf>", line 19
#     contents1=bs.findAll("tr",{"onmouseout":"highlight(this,false)"}. limit=7)
#                              ^
# SyntaxError: keyword can't be an expression

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://finance.daum.net/quote/marketvalue.daum')
#resp.encoding='utf-8-sig'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')

stock_list = bs.select("#myListTop1 > li")
#stock_list = bs.find("ul",{"id":"myListTop1"}).findAll("li")
#stock_list[0].find('a').text
count = 0
stock_nameList = []
stock_priceList = []

for stock_one in stock_list:
    stock_name = stock_one.find('a').text
    stock_price = float(stock_one.find("span",{"class":"cost num"}).text.replace(",",""))
    stock_nameList.append(stock_name)
    stock_priceList.append(stock_price)
    count += 1
list1 = pd.DataFrame(stock_nameList, dtype=str)
stock_priceList
list2 = pd.DataFrame(stock_priceList, dtype=float)
final = pd.concat([list1,list2], axis = 1)
final.columns=['STOCK_NAME','STOCK_PRICE']

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://finance.daum.net/quote/marketvalue.daum')
#resp.encoding='utf-8-sig'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')

stock_list = bs.select("#myListTop1 > li")
#stock_list = bs.find("ul",{"id":"myListTop1"}).findAll("li")
#stock_list[0].find('a').text
count = 0
stock_nameList = []
stock_priceList = []

for stock_one in stock_list:
    stock_name = stock_one.find('a').text
    stock_price = float(stock_one.find("span",{"class":"cost num"}).text.replace(",",""))
    stock_nameList.append(stock_name)
    stock_priceList.append(stock_price)
    count += 1
    #print(count, stock_name, stock_price,count)
list1 = pd.DataFrame(stock_nameList, dtype=str)
stock_priceList
list2 = pd.DataFrame(stock_priceList, dtype=float)
final = pd.concat([list1,list2], axis = 1)
final.columns=['STOCK_NAME','STOCK_PRICE']
final
# Out:
#     STOCK_NAME  STOCK_PRICE
# 0         삼성전자      48450.0
# 1       SK하이닉스      87000.0
# 2         셀트리온     290500.0
# 3        삼성전자우      38550.0
# 4        POSCO     364000.0
# 5          현대차     135500.0
# 6    삼성바이오로직..     414000.0
# 7         LG화학     378000.0
# 8         삼성물산     123000.0
# 9        NAVER     695000.0
# 10        한국전력      35300.0
# 11        KB금융      54100.0
# 12      LG생활건강    1448000.0
# 13       현대모비스     221500.0
# 14        신한지주      45250.0
# 15        삼성생명     102500.0
# 16     SK이노베이션     213500.0
# 17       SK텔레콤     238500.0
# 18          SK     271000.0
# 19      아모레퍼시픽     318000.0
# 20     삼성에스디에스     211000.0
# 21       삼성SDI     234500.0
# 22        LG전자      93500.0
# 23       KT&G;     100500.0
# 24      하나금융지주      44050.0
# 25         기아차      32300.0
# 26          LG      75500.0
# 27         넷마블     149000.0
# 28       롯데케미칼     362500.0
# 29       S-Oil     109000.0
# 30        삼성화재     256500.0
# 31        우리은행      16000.0
# 32        삼성전기     141000.0
# 33        아모레G     124500.0
# 34        기업은행      15850.0

# %%
import pandas as pd
from sqlalchemy import create_engine 
 
# DB 커넥션 열기
engine = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl') 

# 데이터 저장
tablename = "KOPO_STOCK_ST_김효관"
final.to_sql(tablename, engine, if_exists='replace', index=False)

# %%
final
# Out:
#              0          0
# 0         삼성전자    48450.0
# 1       SK하이닉스    87000.0
# 2         셀트리온   290500.0
# 3        삼성전자우    38550.0
# 4        POSCO   364000.0
# 5          현대차   135500.0
# 6    삼성바이오로직..   414000.0
# 7         LG화학   378000.0
# 8         삼성물산   123000.0
# 9        NAVER   695000.0
# 10        한국전력    35300.0
# 11        KB금융    54100.0
# 12      LG생활건강  1448000.0
# 13       현대모비스   221500.0
# 14        신한지주    45250.0
# 15        삼성생명   102500.0
# 16     SK이노베이션   213500.0
# 17       SK텔레콤   238500.0
# 18          SK   271000.0
# 19      아모레퍼시픽   318000.0
# 20     삼성에스디에스   211000.0
# 21       삼성SDI   234500.0
# 22        LG전자    93500.0
# 23       KT&G;   100500.0
# 24      하나금융지주    44050.0
# 25         기아차    32300.0
# 26          LG    75500.0
# 27         넷마블   149000.0
# 28       롯데케미칼   362500.0
# 29       S-Oil   109000.0
# 30        삼성화재   256500.0
# 31        우리은행    16000.0
# 32        삼성전기   141000.0
# 33        아모레G   124500.0
# 34        기업은행    15850.0

# %% [markdown]
# ### 하둡파일시스템 데이터 접근

# %%
# Pandas and hdfs 패키지
import pandas as pd
from hdfs import InsecureClient
import os
# hdfs 설정
client_hdfs = InsecureClient('http://192.168.110.114:50070')

# Test PandasDataFrame 생성 및 넣기
liste_hello = ['hello1','hello2']
liste_world = ['world1','world2']
df = pd.DataFrame(data = {'hello' : liste_hello, 'world': liste_world})

# 데이터프레임 hdfs에 저장
with client_hdfs.write('/mydata/helloworld_kk.csv', encoding = 'utf-8') as writer:
    df.to_csv(writer)

# %%
# 데이터 읽기
# ====== Reading files ======
with client_hdfs.read('/mydata/helloworld.csv', encoding = 'utf-8') as reader:
    readdf=pd.read_csv(reader,index_col=0)

# %%
readdf
# Out:
#     hello   world
# 0  hello1  world1
# 1  hello2  world2

# %%
pd.DataFrame(columns=['STOCK_PRICE'], dtype=float)
# Out:
# Empty DataFrame
# Columns: [STOCK_PRICE]
# Index: []
